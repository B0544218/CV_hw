# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

img_path = 'lena.png'

# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
img_hsv  = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) #HSV和預設一樣
change_percentage = 0.2
img_hsv_down = img_hsv.astype('float32')
print(img_hsv_down[:,:,2])
img_hsv_down[:,:,2] = img_hsv_down[:,:,2]/255 - change_percentage
img_hsv_down[img_hsv_down[:,:,2] < 0] = 0
img_hsv_down[:,:,2] = img_hsv_down[:,:,2]*255
img_hsv_down = img_hsv_down.astype('uint8')

# 在 HSV color space 增加飽和度
img_hsv_up = img_hsv.astype('float32')
img_hsv_up[..., -1] = img_hsv_up[..., -1]/255 + change_percentage
img_hsv_up[img_hsv_up[..., -1] > 1] = 1
img_hsv_up[..., -1] = img_hsv_up[..., -1]*255
img_hsv_up = img_hsv_up.astype('uint8')

# 轉換
img_hsv_down = cv2.cvtColor(img_hsv_down, cv2.COLOR_HLS2BGR)
img_hsv_up = cv2.cvtColor(img_hsv_up, cv2.COLOR_HLS2BGR)
img_hsv_change = np.hstack((img, img_hsv_down, img_hsv_up))

cv2_imshow(img_hsv_change)
# Out:
# [[226. 226. 223. ... 230. 221. 200.]
#  [226. 226. 223. ... 230. 221. 200.]
#  [226. 226. 223. ... 230. 221. 200.]
#  ...
#  [ 84.  84.  92. ... 173. 172. 177.]
#  [ 82.  82.  96. ... 179. 181. 185.]
#  [ 82.  82.  96. ... 179. 181. 185.]]
# <PIL.Image.Image image mode=RGB size=1536x512 at 0x7FBD98127668>
